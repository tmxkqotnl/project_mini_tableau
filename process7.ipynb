# %%
import pandas as pd
import numpy as np

oris = pd.read_csv('./processed/preprocessed_5.csv')
news = pd.read_csv('./processed/preprocessed_2013_5.csv')

# %%
oris.head(3)
new_oris = oris.drop(['Unnamed: 0'],axis=1)

# %%
news.head(3)
new_s = news.drop(['Unnamed: 0'],axis=1)

# %%
temp = pd.concat([new_s,new_oris]).sort_values('계약날짜')

# %%
temp.index = np.arange(0,temp.shape[0])

# %%
temp
# Out:
#                       시군구      번지    본번  부번          단지명  전용면적(㎡)     계약년월  \
# 0           서울특별시 관악구 봉천동    1706  1706   0         봉천우성  59.7600  2006-01
# 1           서울특별시 양천구 신정동     312   312   0      목동신시가지9  53.8200  2006-01
# 2        서울특별시 영등포구 양평동2가    38-1    38   1        삼성래미안  59.4000  2006-01
# 3           서울특별시 노원구 상계동     720   720   0    상계주공6(고층)  59.2000  2006-01
# 4           서울특별시 서초구 잠원동      73    73   0         신반포2  79.4200  2006-01
# ...                   ...     ...   ...  ..          ...      ...      ...
# 1226123     서울특별시 종로구 교북동     126   126   0   경희궁자이(4단지)  45.8790  2022-02
# 1226124       서울특별시 중구 정동      37    37   0    삼정아트테라스정동  14.2664  2022-02
# 1226125   서울특별시 동대문구 답십리동  497-23   497  23     청계푸르지오시티  18.9200  2022-02
# 1226126     서울특별시 관악구 봉천동  1629-2  1629   2         동아타운  28.8000  2022-02
# 1226127     서울특별시 성북구 장위동     8-2     8   2  석계역한일노벨리아시티  15.2144  2022-02
#
# ...

# %%
temp.to_csv('final.csv',encoding='utf-8')
